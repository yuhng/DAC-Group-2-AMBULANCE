# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Dataset 1: Vehicle Crashes

# %%
file_1 = '/Users/yuhngtan/Downloads/Vehicle_Crashes.csv'

df_1 = pd.read_csv(file_1)
# Out:
# /var/folders/32/yk92ldn108zgrfqm8r2sdlkm0000gn/T/ipykernel_31156/1925508220.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv(file_1)

# %%
df_1.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df_1.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.895266e+06  1.895266e+06               2.134641e+06
# mean   4.062558e+01 -7.374824e+01               3.180019e-01
# std    2.001307e+00  3.755992e+00               7.070054e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066761e+01 -7.397472e+01               0.000000e+00
# 50%    4.072060e+01 -7.392710e+01               0.000000e+00
# 75%    4.076962e+01 -7.386678e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.134628e+06                   2.134659e+06
# mean               1.537036e-03                   5.764949e-02
# std                4.139599e-02                   2.462099e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
df_1.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                          object
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
df_1.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           663229
# ZIP CODE                          663491
# LATITUDE                          239393
# LONGITUDE                         239393
# LOCATION                          239393
# ON STREET NAME                    457554
# CROSS STREET NAME                 813846
# OFF STREET NAME                  1769478
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       7203
# CONTRIBUTING FACTOR VEHICLE 2     335261
# CONTRIBUTING FACTOR VEHICLE 3    1981119
# CONTRIBUTING FACTOR VEHICLE 4    2099762
# CONTRIBUTING FACTOR VEHICLE 5    2125151
# ...

# %% [markdown]
# # Dataset 2 : Facilities

# %%
file_2 = '/Users/yuhngtan/Downloads/Facilities_Database_20241117.csv'

df_2 = pd.read_csv(file_2)

# %%
df_2.head()
# Out:
#                                 uid                                 facname  \
# 0  0001056502f70d1eea9f73b4ac96097e        DYCD-EAST RIVER COMMUNITY CENTER
# 1  000186821f899fef28e05c9ca2182621  PLANNED PARENTHOOD BRONX HEALTH CENTER
# 2  00056520e4c5483e13933cda8c8a736d       MARKS JCH OF BENSONHURST DAY CAMP
# 3  0005cf2135820de8d20395875ca0e506               CENTER FOR JEWISH HISTORY
# 4  0006e49b4ecf531c88f5dec8bd7d0364     RELIANT TRANSPORTATION, INC (B2321)
#
#   number           street              address      city    borough  borocode  \
# 0    404  EAST 105 STREET  404 EAST 105 STREET  NEW YORK  MANHATTAN       1.0
# 1    349  EAST 149 STREET  349 EAST 149 STREET     BRONX      BRONX       2.0
# 2   7802      BAY PARKWAY     7802 BAY PARKWAY  BROOKLYN   BROOKLYN       3.0
# 3     15   WEST 16 STREET    15 WEST 16 STREET  NEW YORK  MANHATTAN       1.0
# 4    297    NORMAN AVENUE    297 NORMAN AVENUE  BROOKLYN   BROOKLYN       3.0
#
# ...

# %%
df_2.dtypes
# Out:
# uid                    object
# facname                object
# number                 object
# street                 object
# address                object
# city                   object
# borough                object
# borocode              float64
# postcode              float64
# latitude              float64
# longitude             float64
# xcoord                float64
# ycoord                float64
# bin                   float64
# bbl                   float64
# community district    float64
# council district      float64
# census tract 2010     float64
# census tract 2020     float64
# nta 2010               object
# nta 2020               object
# facgroup               object
# facsubgrp              object
# factype                object
# capacity              float64
# captype                object
# optype                 object
# opname                 object
# opabbrev               object
# overlevel              object
# overagency             object
# ...

# %%
df_2.isnull().sum()
# Out:
# uid                       0
# facname                   8
# number                 5933
# street                 5591
# address                3417
# city                    198
# borough                 163
# borocode                163
# postcode                345
# latitude                742
# longitude               742
# xcoord                  742
# ycoord                  742
# bin                    5533
# bbl                    2086
# community district      883
# council district        892
# census tract 2010       883
# census tract 2020       883
# nta 2010                883
# nta 2020                883
# facgroup                  0
# facsubgrp                 0
# factype                  59
# capacity              33377
# captype               33176
# optype                 9809
# opname                 1051
# opabbrev               9797
# overlevel               703
# overagency                7
# overabbrev                0
# datasource                0
# ...
